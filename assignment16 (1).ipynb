# %%
#                                     ANSWER 1 
#Flask is a micro web framework written in Python. It is classified as a microframework because it does not require particular tools or libraries.
#Advantages of Flask Framework:
#Scalable : Size is everything, and Flask’s status as a microframework means that you can use it to grow a tech project such as a web app incredibly quickly.
#Flexible : This is the core feature of Flask, and one of its biggest advantages. 
#Easy to negotiate : Like Django, being able to find your way around easily is key for allowing web developers to concentrate on just coding quickly, without getting bogged down.
#Lightweight : This design gives web developers a certain level of control.
#Documentation : Nice documentation design makes you actually write documentation.

# %%
#                                             ANSWER 2 
#from flask import Flask

#app = Flask(__name__)

#@app.route("/")
#def hello_world():
#    return "<h1>Hello World!!</h1>"

#if __name__=="__main__":
#    app.run(host="0.0.0.0")

# %% [markdown]
#                                                 ANSWER 2
# ![Screenshot (173).png](attachment:9f2a5cf9-893f-4bf3-8242-f1accd94e69f.png)

# %%
#                                            ANSWER 3
#from flask import Flask

#app = Flask(__name__)

#@app.route("/welcome")
#def welcome():
#    return "<h1>Welcome to ABC Corporation</h1>"

#@app.route("/")
#def corrporation():
#    return"<h2>Company Name: ABC Corporation</h2>" "<h3>Location: India </h3>" "<h4>Contact Detail: 999-999-9999</h4>"

#if __name__=="__main__":
#    app.run(host="0.0.0.0")

# %% [markdown]
#                                              ANSWER 3
# ![Screenshot (172).png](attachment:11b7e2e8-d4de-485e-8fe9-5fb90e26610f.png)
# ![Screenshot (171).png](attachment:598b6df5-1776-4949-9a6b-9d7445f02a1c.png)

# %%
#                                             ANSWER 4
#To build a URL to a specific function, use the url_for() function. 
#from flask import Flask , url_for , redirect

#app = Flask(__name__)

#@app.route("/world")
#def hello_world():
#    return "<h1>Hello, World!!!!</h1>"

#@app.route("/india")
#def hello_india():
#    return redirect(url_for("hello_world"))

#@app.route("/RBL")
#def hello_RBL():
#    return url_for("hello_india")

#if __name__=="__main__":
#    app.run(host="0.0.0.0")
